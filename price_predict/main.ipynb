# %% [markdown]
# The dataset is here:
# https://huggingface.co/datasets/McAuley-Lab/Amazon-Reviews-2023
#
# And the folder with all the product datasets is here:
# https://huggingface.co/datasets/McAuley-Lab/Amazon-Reviews-2023/tree/main/raw/meta_categories

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import login
from datasets import load_dataset, DatasetDict, Dataset
import matplotlib.pyplot as plt
from openai import OpenAI

# %%
dotenv_path = os.path.join(os.path.dirname(os.getcwd()), '.env')
dotenv_path
# Out:
# '/Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/.env'

# %%
load_dotenv(dotenv_path, override=True)
api_key = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_API_KEY"] = api_key
hf_token = os.getenv("HF_TOKEN")
os.environ["HF_TOKEN"] = hf_token
openai = OpenAI()
login(token=hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# !pip install datasets==3.6.0
# Out:
# Requirement already satisfied: datasets==3.6.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: filelock in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (2.3.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (0.3.8)
# Requirement already satisfied: pandas in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (4.67.1)
# Requirement already satisfied: xxhash in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (0.36.0)
# Requirement already satisfied: packaging in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from datasets==3.6.0) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets==3.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets==3.6.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets==3.6.0) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/soroushav/Desktop/projects/LLM_Engineering/expert-knowledge-worker/llm_basics/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
dataset = load_dataset("McAuley-Lab/Amazon-Reviews-2023", f"raw_meta_Appliances", split="full", trust_remote_code=True)

# %%
datapoint = dataset[2]
print(datapoint)
# Out:
# {'main_category': 'Tools & Home Improvement', 'title': 'Clothes Dryer Drum Slide, General Electric, Hotpoint, WE1M333, WE1M504', 'average_rating': 3.5, 'rating_number': 18, 'features': [], 'description': ['Brand new dryer drum slide, replaces General Electric, Hotpoint, RCA, WE1M333, WE1M504.'], 'price': 'None', 'images': {'hi_res': ['https://m.media-amazon.com/images/I/51TIpnkrEpL._AC_SL1500_.jpg'], 'large': ['https://m.media-amazon.com/images/I/21HQKcHPIkL._AC_.jpg'], 'thumb': ['https://m.media-amazon.com/images/I/21HQKcHPIkL._AC_US75_.jpg'], 'variant': ['MAIN']}, 'videos': {'title': [], 'url': [], 'user_id': []}, 'store': 'GE', 'categories': ['Appliances', 'Parts & Accessories'], 'details': '{"Manufacturer": "RPI", "Part Number": "WE1M333,", "Item Weight": "0.352 ounces", "Package Dimensions": "5.5 x 4.7 x 0.4 inches", "Item model number": "WE1M333,", "Is Discontinued By Manufacturer": "No", "Item Package Quantity": "1", "Batteries Included?": "No", "Batteries Required?": "No", "Best Sellers Rank": {"Tools & Home Improvement": 1315213, "Parts & Accessories": 181194}, "Date First Available": "February 25, 2014"}', 'parent_asin': 'B00IN9AGAE', 'bought_together': None, 'subtitle': None, 'author': None}

# %%
print(f"Number of Appliances: {len(dataset):,}")
# Out:
# Number of Appliances: 94,327

# %%
print(datapoint["title"])
print(datapoint["description"])
print(datapoint["features"])
print(datapoint["details"])
print(datapoint["price"])
# Out:
# Clothes Dryer Drum Slide, General Electric, Hotpoint, WE1M333, WE1M504
# ['Brand new dryer drum slide, replaces General Electric, Hotpoint, RCA, WE1M333, WE1M504.']
# []
# {"Manufacturer": "RPI", "Part Number": "WE1M333,", "Item Weight": "0.352 ounces", "Package Dimensions": "5.5 x 4.7 x 0.4 inches", "Item model number": "WE1M333,", "Is Discontinued By Manufacturer": "No", "Item Package Quantity": "1", "Batteries Included?": "No", "Batteries Required?": "No", "Best Sellers Rank": {"Tools & Home Improvement": 1315213, "Parts & Accessories": 181194}, "Date First Available": "February 25, 2014"}
# None

# %%
from items import Item
# %matplotlib inline
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]

# %%
# For those with prices, gather the price and the length

prices = []
lengths = []
for datapoint in dataset:
    try:
        price = float(datapoint["price"])
        if price > 0:
            prices.append(price)
            contents = datapoint["title"] + str(datapoint["description"]) + str(datapoint["features"]) + str(datapoint["details"])
            lengths.append(len(contents))
    except ValueError as e:
        pass

# %%
# Plot the distribution of lengths

plt.figure(figsize=(15, 6))
plt.title(f"Lengths: Avg {sum(lengths)/len(lengths):,.0f} and highest {max(lengths):,}\n")
plt.xlabel('Length (chars)')
plt.ylabel('Count')
plt.hist(lengths, rwidth=0.7, color="lightblue", bins=range(0, 6000, 100))
plt.show()

# %%
# plot the distribution of prices

plt.figure(figsize=(15, 6))
plt.title(f"Prices, average: {sum(prices)/len(prices):,.0f} and highest: {max(prices):,.0f}")
plt.xlabel("Prices")
plt.ylabel("Count")
plt.hist(prices, rwidth=0.7, color="red", bins=range(0, 1000, 10))
plt.show()
